# %% [markdown]
# #Asignatura: Visión por Computador

# %% [markdown]
# ##Alumnos: Yeray Álvarez-Buylla Parra, María Elena Navarro Santana

# %% [markdown]
# ##Práctica 4

# %% [markdown]
# ###Paquetes necesarios

# %%
import math 

from ultralytics import YOLO

import csv
import cv2
from ultralytics import YOLO
from collections import defaultdict, deque
import easyocr
import time

# %% [markdown]
# TAREA: desarrollar un prototipo que procese uno (vídeo ejemplo proporcionado) o varios vídeos (incluyendo vídeos de cosecha propia):
# - detecte y siga las personas y vehículos presentes
# - detecte y lea las matrículas de los vehículos presentes
# - cuente el total de cada clase
# - vuelque a disco un vídeo que visualice los resultados
# - genere un archivo csv con el resultado de la detección y seguimiento. Se sugiere un formato con al menos los siguientes campos:
#
# fotograma, tipo_objeto, confianza, identificador_tracking, x1, y1, x2, y2, matrícula_en_su_caso, confianza, mx1,my1,mx2,my2, texto_matricula

# %%
# Etiquetas de las clases
classNames = ["matricula", "person", "car", "motorbike"]

# Carga el modelo YOLO y el modelo entrenado de 100 épocas
modelo_general = YOLO('yolo11n.pt')  
modelo_matriculas = YOLO('best.pt')   

# Inicialización del contador para cada clase
contador_clases = defaultdict(int)

# Archivo de video a analizar
filename = "video_2.mp4"

# Inicialización del lector OCR
lector_ocr = easyocr.Reader(['es'], gpu=False)

# Lista de matrículas detectadas y tiempo de detección
matriculas_detectadas = deque(maxlen=10)  # Mantiene un máximo de 10 matrículas visibles
tiempo_visibilidad = 5  # Tiempo en segundos que se mantendrá visible una matrícula detectada

# Nombre del archivo CSV
csv_filename = "detecciones.csv"

# Crea el archivo CSV y escribe el encabezado
with open(csv_filename, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow([
        "fotograma", "tipo_objeto", "confianza", "identificador_tracking",
        "x1", "y1", "x2", "y2", "matricula_en_su_caso", "confianza_matricula",
        "mx1", "my1", "mx2", "my2", "texto_matricula"
    ])

# Configuración para guardar un video con las detecciones
cap = cv2.VideoCapture(filename)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)
out = cv2.VideoWriter('video_2_detecciones.mp4', cv2.VideoWriter_fourcc(*'mp4v'), fps, (width, height))

# Función para validar matrículas
def es_matricula_valida(texto):
    texto = texto.replace(" ", "")
    return len(texto) == 7 and texto[:4].isdigit() and texto[4:].isalpha()

# Función para procesar detecciones de vehículos y personas
def procesar_detecciones_generales(results, frame, fotograma_num):
    vehiculos = []
    posiciones_vehiculos = []
    
    for result in results:
        for box in result.boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            confidence = round(box.conf[0].item(), 2)
            class_id = int(box.cls[0])  # Índice de clase del objeto detectado
            
            # Asegurarse de que solo se procesen personas, coches y motos en yolo11n.pt
            if class_id < len(classNames) and classNames[class_id] in ["person", "car", "motorbike"]:
                tipo_objeto = classNames[class_id]  # Nombre de la clase detectada
                
                # Definir color según el tipo de objeto
                color = (0, 0, 255) if tipo_objeto == "person" else (255, 0, 0)
                
                # Dibujar el rectángulo y etiqueta en el frame
                cv2.rectangle(frame, (x1, y1), (x2, y2), color, 3)
                cv2.putText(frame, f"{tipo_objeto} {confidence}", (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, color, 2)
                
                # Registrar solo coches y motos para OCR y detección de matrículas
                if tipo_objeto in ["car", "motorbike"]:
                    vehiculos.append(frame[y1:y2, x1:x2])  # Extraer el vehículo detectado
                    posiciones_vehiculos.append((x1, y1))  # Guardar la posición para cálculo global

                # Escribir en el CSV la detección de cada objeto
                with open(csv_filename, mode='a', newline='') as file:
                    writer = csv.writer(file)
                    writer.writerow([
                        fotograma_num, tipo_objeto, confidence, class_id,
                        x1, y1, x2, y2, "", "", "", "", "", ""
                    ])
    
    return vehiculos, posiciones_vehiculos

# Función para procesar detecciones de matrículas dentro de los vehículos
def procesar_detecciones_matriculas(vehiculos, posiciones_vehiculos, frame, fotograma_num):
    for idx, vehiculo in enumerate(vehiculos):
        results = modelo_matriculas(vehiculo)
        
        for result in results:
            for box in result.boxes:
                x1, y1, x2, y2 = map(int, box.xyxy[0])
                confidence = round(box.conf[0].item(), 2)
                
                if confidence > 0.5:
                    # Se calcula la posición global de la matrícula
                    x1_global = posiciones_vehiculos[idx][0] + x1
                    y1_global = posiciones_vehiculos[idx][1] + y1
                    x2_global = posiciones_vehiculos[idx][0] + x2
                    y2_global = posiciones_vehiculos[idx][1] + y2
                    
                    # Dibuja el recuadro y etiqueta de matrícula
                    cv2.rectangle(frame, (x1_global, y1_global), (x2_global, y2_global), (0, 255, 0), 3)
                    cv2.putText(frame, f"matricula {confidence}", (x1_global, y1_global - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

                    # Extrae y procesa OCR en la imagen de la matrícula
                    placa_imagen = frame[y1_global:y2_global, x1_global:x2_global]
                    resultado_ocr = lector_ocr.readtext(placa_imagen)
                    
                    texto_matricula = ''
                    if resultado_ocr:
                        textos_detectados = [item[1] for item in resultado_ocr]
                        texto_matricula = ' '.join(textos_detectados)
                        matriculas_detectadas.append((texto_matricula, time.time()))
                    
                    # Escribe en el CSV la detección de la matrícula
                    with open(csv_filename, mode='a', newline='') as file:
                        writer = csv.writer(file)
                        writer.writerow([
                            fotograma_num, "matricula", confidence, idx,
                            x1_global, y1_global, x2_global, y2_global,
                            "matricula", confidence,
                            x1, y1, x2, y2, texto_matricula
                        ])

# Función para mostrar matrículas en pantalla
def mostrar_matriculas_en_pantalla(frame):
    matriculas_a_mostrar = [mat for mat, t in matriculas_detectadas if time.time() - t < tiempo_visibilidad]
    
    for idx, matricula in enumerate(matriculas_a_mostrar):
        cv2.putText(frame, f'Matricula: {matricula}', (10, 30 + idx * 30), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)

# Procesa el video con detección en tiempo real
fotograma_num = 0

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    
    fotograma_num += 1
    results_generales = modelo_general(frame)
    vehiculos, posiciones_vehiculos = procesar_detecciones_generales(results_generales, frame, fotograma_num)
    
    if vehiculos:
        procesar_detecciones_matriculas(vehiculos, posiciones_vehiculos, frame, fotograma_num)
    
    mostrar_matriculas_en_pantalla(frame)
    cv2.imshow('Detector de Matriculas', frame)
    
    # Escribe el frame con las detecciones en el video de salida
    out.write(frame)
    
    if cv2.waitKey(1) & 0xFF == 27:
        break

# Libera los recursos
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# 0: 640x384 1 car, 1 motorcycle, 1 stop sign, 149.5ms
# Speed: 1.9ms preprocess, 149.5ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x352 (no detections), 97.4ms
# Speed: 1.6ms preprocess, 97.4ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 352)
#
# 0: 416x416 (no detections), 108.7ms
# Speed: 1.0ms preprocess, 108.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 640x384 1 car, 1 motorcycle, 1 stop sign, 91.0ms
# Speed: 2.4ms preprocess, 91.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x384 (no detections), 101.7ms
# Speed: 1.3ms preprocess, 101.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 416x416 (no detections), 78.5ms
# Speed: 1.0ms preprocess, 78.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 640x384 1 car, 1 motorcycle, 1 stop sign, 94.3ms
# Speed: 2.0ms preprocess, 94.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x384 (no detections), 70.1ms
# Speed: 1.2ms preprocess, 70.1ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 416x416 (no detections), 73.6ms
# Speed: 1.1ms preprocess, 73.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 640x384 1 car, 1 motorcycle, 1 stop sign, 85.8ms
# Speed: 1.5ms preprocess, 85.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x384 (no detections), 79.6ms
# Speed: 0.9ms preprocess, 79.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 416x384 (no detections), 61.2ms
# Speed: 1.0ms preprocess, 61.2ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 640x384 1 car, 1 motorcycle, 1 stop sign, 99.0ms
# Speed: 2.0ms preprocess, 99.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x384 (no detections), 68.8ms
# Speed: 1.0ms preprocess, 68.8ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 416x384 (no detections), 64.5ms
# Speed: 1.0ms preprocess, 64.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 640x384 2 cars, 1 motorcycle, 78.7ms
# Speed: 2.0ms preprocess, 78.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x384 (no detections), 71.0ms
# Speed: 1.0ms preprocess, 71.0ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 416x352 (no detections), 63.8ms
# Speed: 1.1ms preprocess, 63.8ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 352)
#
# 0: 288x416 (no detections), 55.4ms
# Speed: 1.1ms preprocess, 55.4ms inference, 0.0ms postprocess per image at shape (1, 3, 288, 416)
#
# 0: 640x384 1 car, 1 motorcycle, 1 stop sign, 80.4ms
# Speed: 1.9ms preprocess, 80.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x384 (no detections), 57.5ms
# Speed: 0.0ms preprocess, 57.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 416x384 (no detections), 57.5ms
# Speed: 1.1ms preprocess, 57.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 640x384 1 car, 1 motorcycle, 1 stop sign, 92.2ms
# Speed: 1.0ms preprocess, 92.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x384 (no detections), 82.5ms
# Speed: 1.0ms preprocess, 82.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 416x384 (no detections), 54.0ms
# Speed: 1.0ms preprocess, 54.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 640x384 1 car, 1 motorcycle, 1 stop sign, 103.4ms
# Speed: 1.0ms preprocess, 103.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x384 (no detections), 64.7ms
# Speed: 1.0ms preprocess, 64.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 416x352 (no detections), 88.0ms
# Speed: 2.0ms preprocess, 88.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 352)
#
# 0: 640x384 1 car, 1 motorcycle, 1 stop sign, 75.9ms
# Speed: 1.4ms preprocess, 75.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x384 (no detections), 60.7ms
# Speed: 1.6ms preprocess, 60.7ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 416x384 (no detections), 70.6ms
# Speed: 0.9ms preprocess, 70.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 640x384 1 car, 1 motorcycle, 1 stop sign, 124.1ms
# Speed: 2.0ms preprocess, 124.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x352 (no detections), 64.9ms
# Speed: 0.9ms preprocess, 64.9ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 352)
#
# 0: 416x384 (no detections), 87.4ms
# Speed: 1.6ms preprocess, 87.4ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 640x384 1 car, 1 motorcycle, 1 stop sign, 103.4ms
# Speed: 1.9ms preprocess, 103.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x384 (no detections), 63.1ms
# Speed: 0.9ms preprocess, 63.1ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 416x384 (no detections), 89.1ms
# Speed: 0.0ms preprocess, 89.1ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 640x384 1 car, 1 motorcycle, 93.7ms
# Speed: 2.1ms preprocess, 93.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x352 (no detections), 60.2ms
# Speed: 1.2ms preprocess, 60.2ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 352)
#
# 0: 416x384 (no detections), 68.3ms
# Speed: 0.0ms preprocess, 68.3ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 640x384 1 car, 1 motorcycle, 1 stop sign, 85.9ms
# Speed: 1.0ms preprocess, 85.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x352 (no detections), 69.5ms
# Speed: 0.6ms preprocess, 69.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 352)
#
# 0: 416x352 (no detections), 69.8ms
# Speed: 1.1ms preprocess, 69.8ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 352)
#
# 0: 640x384 1 car, 1 motorcycle, 1 stop sign, 75.7ms
# Speed: 1.0ms preprocess, 75.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x352 (no detections), 57.7ms
# Speed: 1.0ms preprocess, 57.7ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 352)
#
# 0: 416x352 (no detections), 65.4ms
# Speed: 1.0ms preprocess, 65.4ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 352)
#
# 0: 640x384 1 car, 1 motorcycle, 1 stop sign, 84.2ms
# Speed: 0.9ms preprocess, 84.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x352 (no detections), 67.1ms
# Speed: 0.0ms preprocess, 67.1ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 352)
#
# 0: 416x384 (no detections), 70.5ms
# Speed: 1.1ms preprocess, 70.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 640x384 1 car, 1 motorcycle, 1 stop sign, 91.1ms
# Speed: 2.0ms preprocess, 91.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x352 (no detections), 71.6ms
# Speed: 1.5ms preprocess, 71.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 352)
#
# 0: 416x384 (no detections), 74.9ms
# Speed: 1.1ms preprocess, 74.9ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 640x384 1 car, 1 motorcycle, 1 stop sign, 95.9ms
# Speed: 1.0ms preprocess, 95.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x352 (no detections), 73.8ms
# Speed: 1.0ms preprocess, 73.8ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 352)
#
# 0: 416x384 (no detections), 132.8ms
# Speed: 3.0ms preprocess, 132.8ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 640x384 1 car, 1 motorcycle, 1 stop sign, 81.6ms
# Speed: 2.4ms preprocess, 81.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x352 (no detections), 64.6ms
# Speed: 1.1ms preprocess, 64.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 352)
#
# 0: 416x384 (no detections), 64.1ms
# Speed: 0.0ms preprocess, 64.1ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 640x384 1 car, 1 motorcycle, 1 stop sign, 91.2ms
# Speed: 1.0ms preprocess, 91.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x320 (no detections), 86.6ms
# Speed: 1.0ms preprocess, 86.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 320)
#
# 0: 416x384 (no detections), 61.6ms
# Speed: 1.0ms preprocess, 61.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 640x384 1 car, 1 motorcycle, 1 stop sign, 78.9ms
# Speed: 2.1ms preprocess, 78.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x384 (no detections), 64.5ms
# Speed: 1.3ms preprocess, 64.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 416x320 (no detections), 63.5ms
# Speed: 1.3ms preprocess, 63.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 320)
#
# 0: 640x384 1 car, 1 motorcycle, 1 stop sign, 77.1ms
# Speed: 1.1ms preprocess, 77.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x352 (no detections), 61.5ms
# Speed: 0.0ms preprocess, 61.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 352)
#
# 0: 416x384 (no detections), 71.6ms
# Speed: 0.0ms preprocess, 71.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 640x384 1 car, 1 motorcycle, 1 stop sign, 86.7ms
# Speed: 2.1ms preprocess, 86.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x320 (no detections), 64.4ms
# Speed: 1.0ms preprocess, 64.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 320)
#
# 0: 416x384 (no detections), 81.0ms
# Speed: 1.0ms preprocess, 81.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 640x384 1 car, 1 motorcycle, 1 stop sign, 103.5ms
# Speed: 1.0ms preprocess, 103.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x384 (no detections), 71.4ms
# Speed: 0.9ms preprocess, 71.4ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 416x288 (no detections), 67.1ms
# Speed: 1.2ms preprocess, 67.1ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 288)
#
# 0: 640x384 1 car, 1 motorcycle, 1 stop sign, 75.9ms
# Speed: 1.1ms preprocess, 75.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x288 (no detections), 61.3ms
# Speed: 1.0ms preprocess, 61.3ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 288)
#
# 0: 416x384 (no detections), 64.3ms
# Speed: 1.0ms preprocess, 64.3ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 640x384 1 car, 1 motorcycle, 1 stop sign, 89.1ms
# Speed: 1.0ms preprocess, 89.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x320 (no detections), 60.9ms
# Speed: 1.1ms preprocess, 60.9ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 320)
#
# 0: 416x384 1 matricula, 66.0ms
# Speed: 1.2ms preprocess, 66.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 640x384 1 car, 1 motorcycle, 1 stop sign, 91.3ms
# Speed: 2.1ms preprocess, 91.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x320 (no detections), 57.3ms
# Speed: 0.9ms preprocess, 57.3ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 320)
#
# 0: 416x384 (no detections), 60.4ms
# Speed: 1.0ms preprocess, 60.4ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 640x384 1 car, 1 motorcycle, 2 stop signs, 91.0ms
# Speed: 1.6ms preprocess, 91.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x320 (no detections), 58.9ms
# Speed: 1.1ms preprocess, 58.9ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 320)
#
# 0: 416x384 (no detections), 77.3ms
# Speed: 1.0ms preprocess, 77.3ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 640x384 1 car, 1 motorcycle, 2 stop signs, 107.6ms
# Speed: 0.9ms preprocess, 107.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x384 (no detections), 70.9ms
# Speed: 0.9ms preprocess, 70.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 416x320 (no detections), 59.7ms
# Speed: 1.7ms preprocess, 59.7ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 320)
#
# 0: 640x384 1 car, 1 motorcycle, 1 stop sign, 81.9ms
# Speed: 1.9ms preprocess, 81.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x288 (no detections), 53.2ms
# Speed: 0.9ms preprocess, 53.2ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 288)
#
# 0: 416x384 (no detections), 66.2ms
# Speed: 1.5ms preprocess, 66.2ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 640x384 1 car, 1 motorcycle, 2 stop signs, 80.4ms
# Speed: 1.1ms preprocess, 80.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x384 (no detections), 92.4ms
# Speed: 1.0ms preprocess, 92.4ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 416x256 (no detections), 69.7ms
# Speed: 1.0ms preprocess, 69.7ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 256)
#
# 0: 640x384 1 car, 1 motorcycle, 2 stop signs, 92.4ms
# Speed: 2.1ms preprocess, 92.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x384 (no detections), 71.9ms
# Speed: 1.7ms preprocess, 71.9ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 416x288 (no detections), 71.1ms
# Speed: 1.0ms preprocess, 71.1ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 288)
#
# 0: 640x384 1 car, 1 motorcycle, 2 stop signs, 133.6ms
# Speed: 2.0ms preprocess, 133.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x256 (no detections), 116.5ms
# Speed: 2.1ms preprocess, 116.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 256)
#
# 0: 416x384 (no detections), 118.2ms
# Speed: 1.0ms preprocess, 118.2ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 640x384 1 car, 1 motorcycle, 2 stop signs, 145.1ms
# Speed: 1.0ms preprocess, 145.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x384 (no detections), 112.5ms
# Speed: 1.0ms preprocess, 112.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 416x288 (no detections), 111.4ms
# Speed: 1.0ms preprocess, 111.4ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 288)
#
# 0: 640x384 1 car, 1 motorcycle, 2 stop signs, 142.1ms
# Speed: 2.0ms preprocess, 142.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x384 (no detections), 122.6ms
# Speed: 1.8ms preprocess, 122.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 416x256 (no detections), 96.8ms
# Speed: 2.1ms preprocess, 96.8ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 256)
#
# 0: 640x384 1 car, 1 motorcycle, 1 stop sign, 137.7ms
# Speed: 1.6ms preprocess, 137.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x384 (no detections), 116.0ms
# Speed: 1.1ms preprocess, 116.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 416x256 (no detections), 98.5ms
# Speed: 1.0ms preprocess, 98.5ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 256)
#
# 0: 640x384 1 car, 1 motorcycle, 1 stop sign, 143.8ms
# Speed: 1.6ms preprocess, 143.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x384 (no detections), 127.6ms
# Speed: 1.0ms preprocess, 127.6ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 416x256 (no detections), 103.5ms
# Speed: 1.6ms preprocess, 103.5ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 256)
#
# 0: 640x384 1 car, 1 motorcycle, 1 stop sign, 145.0ms
# Speed: 1.0ms preprocess, 145.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x384 (no detections), 104.8ms
# Speed: 2.5ms preprocess, 104.8ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 416x224 (no detections), 120.0ms
# Speed: 2.0ms preprocess, 120.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 224)
#
# 0: 640x384 1 car, 1 motorcycle, 1 stop sign, 145.5ms
# Speed: 2.2ms preprocess, 145.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x384 (no detections), 111.2ms
# Speed: 1.0ms preprocess, 111.2ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 416x192 (no detections), 105.9ms
# Speed: 1.0ms preprocess, 105.9ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 192)
#
# 0: 640x384 1 car, 1 motorcycle, 1 stop sign, 148.8ms
# Speed: 3.0ms preprocess, 148.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x384 (no detections), 112.0ms
# Speed: 1.6ms preprocess, 112.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 416x192 (no detections), 63.5ms
# Speed: 1.0ms preprocess, 63.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 192)
#
# 0: 640x384 1 car, 1 motorcycle, 1 stop sign, 145.1ms
# Speed: 2.5ms preprocess, 145.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x384 (no detections), 107.3ms
# Speed: 1.1ms preprocess, 107.3ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 416x192 (no detections), 92.9ms
# Speed: 1.0ms preprocess, 92.9ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 192)
#
# 0: 640x384 1 car, 1 motorcycle, 1 stop sign, 132.7ms
# Speed: 2.4ms preprocess, 132.7ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x352 (no detections), 131.7ms
# Speed: 1.0ms preprocess, 131.7ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 352)
#
# 0: 416x192 (no detections), 85.7ms
# Speed: 1.0ms preprocess, 85.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
#
# 0: 640x384 1 car, 1 motorcycle, 1 stop sign, 138.7ms
# Speed: 1.1ms preprocess, 138.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x352 (no detections), 105.8ms
# Speed: 1.0ms preprocess, 105.8ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 352)
#
# 0: 416x192 (no detections), 80.9ms
# Speed: 1.0ms preprocess, 80.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
#
# 0: 640x384 1 car, 1 motorcycle, 1 stop sign, 142.5ms
# Speed: 2.3ms preprocess, 142.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x352 1 matricula, 128.4ms
# Speed: 0.9ms preprocess, 128.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 352)
#
# 0: 416x192 (no detections), 78.8ms
# Speed: 1.6ms preprocess, 78.8ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 192)
#
# 0: 640x384 1 car, 1 motorcycle, 1 stop sign, 136.4ms
# Speed: 1.8ms preprocess, 136.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x384 1 matricula, 123.8ms
# Speed: 1.0ms preprocess, 123.8ms inference, 2.1ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 416x96 (no detections), 90.3ms
# Speed: 0.0ms preprocess, 90.3ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 96)
#
# 0: 640x384 1 motorcycle, 1 stop sign, 138.7ms
# Speed: 1.9ms preprocess, 138.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x384 1 matricula, 139.1ms
# Speed: 2.0ms preprocess, 139.1ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 640x384 1 motorcycle, 1 stop sign, 134.0ms
# Speed: 2.0ms preprocess, 134.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x384 1 matricula, 119.6ms
# Speed: 2.0ms preprocess, 119.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 640x384 1 motorcycle, 1 stop sign, 145.1ms
# Speed: 1.5ms preprocess, 145.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x416 1 matricula, 114.8ms
# Speed: 1.0ms preprocess, 114.8ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 640x384 1 motorcycle, 1 stop sign, 132.3ms
# Speed: 3.0ms preprocess, 132.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x384 (no detections), 145.7ms
# Speed: 1.0ms preprocess, 145.7ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 640x384 1 motorcycle, 1 stop sign, 176.2ms
# Speed: 3.1ms preprocess, 176.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x384 (no detections), 131.3ms
# Speed: 1.1ms preprocess, 131.3ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 640x384 1 motorcycle, 1 stop sign, 155.7ms
# Speed: 2.8ms preprocess, 155.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x384 (no detections), 140.0ms
# Speed: 2.4ms preprocess, 140.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 640x384 1 motorcycle, 1 stop sign, 146.0ms
# Speed: 3.0ms preprocess, 146.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x384 (no detections), 118.1ms
# Speed: 1.0ms preprocess, 118.1ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 640x384 1 motorcycle, 1 stop sign, 132.8ms
# Speed: 2.0ms preprocess, 132.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x384 (no detections), 133.2ms
# Speed: 2.4ms preprocess, 133.2ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 640x384 1 motorcycle, 1 stop sign, 165.3ms
# Speed: 2.0ms preprocess, 165.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x384 1 matricula, 121.8ms
# Speed: 2.1ms preprocess, 121.8ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 640x384 1 motorcycle, 166.8ms
# Speed: 1.0ms preprocess, 166.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x416 (no detections), 119.0ms
# Speed: 1.0ms preprocess, 119.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 640x384 1 motorcycle, 1 stop sign, 146.0ms
# Speed: 2.3ms preprocess, 146.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x384 1 matricula, 146.0ms
# Speed: 1.5ms preprocess, 146.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 640x384 1 motorcycle, 125.9ms
# Speed: 1.0ms preprocess, 125.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x384 1 matricula, 95.3ms
# Speed: 1.0ms preprocess, 95.3ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 640x384 1 motorcycle, 117.9ms
# Speed: 2.0ms preprocess, 117.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x384 1 matricula, 96.0ms
# Speed: 1.0ms preprocess, 96.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 640x384 1 motorcycle, 1 stop sign, 134.5ms
# Speed: 2.8ms preprocess, 134.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x384 1 matricula, 101.1ms
# Speed: 1.5ms preprocess, 101.1ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 640x384 1 motorcycle, 1 stop sign, 137.6ms
# Speed: 2.0ms preprocess, 137.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x384 1 matricula, 98.2ms
# Speed: 1.0ms preprocess, 98.2ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 640x384 1 motorcycle, 149.0ms
# Speed: 1.0ms preprocess, 149.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x352 1 matricula, 105.3ms
# Speed: 1.6ms preprocess, 105.3ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 352)
#
# 0: 640x384 1 car, 1 motorcycle, 1 stop sign, 144.9ms
# Speed: 1.0ms preprocess, 144.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x352 1 matricula, 100.5ms
# Speed: 2.4ms preprocess, 100.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 352)
#
# 0: 256x416 (no detections), 73.4ms
# Speed: 1.5ms preprocess, 73.4ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 1 car, 1 motorcycle, 1 stop sign, 111.5ms
# Speed: 2.1ms preprocess, 111.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x352 1 matricula, 79.6ms
# Speed: 1.0ms preprocess, 79.6ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 352)
#
# 0: 256x416 (no detections), 69.1ms
# Speed: 1.0ms preprocess, 69.1ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 1 motorcycle, 1 stop sign, 127.6ms
# Speed: 2.0ms preprocess, 127.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x352 1 matricula, 81.1ms
# Speed: 1.6ms preprocess, 81.1ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 352)
#
# 0: 640x384 1 motorcycle, 1 stop sign, 114.3ms
# Speed: 2.0ms preprocess, 114.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x384 1 matricula, 106.0ms
# Speed: 1.0ms preprocess, 106.0ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 640x384 1 motorcycle, 1 stop sign, 111.1ms
# Speed: 1.9ms preprocess, 111.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x352 1 matricula, 75.0ms
# Speed: 1.0ms preprocess, 75.0ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 352)
#
# 0: 640x384 1 motorcycle, 1 stop sign, 99.3ms
# Speed: 1.5ms preprocess, 99.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x352 1 matricula, 88.0ms
# Speed: 1.0ms preprocess, 88.0ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 352)
#
# 0: 640x384 1 motorcycle, 1 stop sign, 123.1ms
# Speed: 1.9ms preprocess, 123.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x384 1 matricula, 83.2ms
# Speed: 1.0ms preprocess, 83.2ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 640x384 1 motorcycle, 1 stop sign, 122.6ms
# Speed: 2.2ms preprocess, 122.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x352 (no detections), 80.1ms
# Speed: 1.2ms preprocess, 80.1ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 352)
#
# 0: 640x384 1 motorcycle, 1 stop sign, 108.9ms
# Speed: 2.0ms preprocess, 108.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x352 1 matricula, 85.0ms
# Speed: 1.0ms preprocess, 85.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 352)
#
# 0: 640x384 1 motorcycle, 113.8ms
# Speed: 3.3ms preprocess, 113.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x352 1 matricula, 84.5ms
# Speed: 1.0ms preprocess, 84.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 352)
#
# 0: 640x384 1 motorcycle, 1 stop sign, 122.8ms
# Speed: 2.0ms preprocess, 122.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x352 (no detections), 93.7ms
# Speed: 1.0ms preprocess, 93.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 352)
#
# 0: 640x384 1 motorcycle, 1 stop sign, 146.1ms
# Speed: 2.0ms preprocess, 146.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x352 (no detections), 86.2ms
# Speed: 0.9ms preprocess, 86.2ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 352)
#
# 0: 640x384 1 motorcycle, 1 stop sign, 111.3ms
# Speed: 2.0ms preprocess, 111.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x320 1 matricula, 83.9ms
# Speed: 2.2ms preprocess, 83.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 320)
#
# 0: 640x384 1 motorcycle, 1 stop sign, 114.8ms
# Speed: 2.0ms preprocess, 114.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x352 1 matricula, 101.7ms
# Speed: 2.6ms preprocess, 101.7ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 352)
#
# 0: 640x384 1 motorcycle, 1 stop sign, 137.9ms
# Speed: 0.9ms preprocess, 137.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x320 1 matricula, 104.7ms
# Speed: 2.0ms preprocess, 104.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 320)
#
# 0: 640x384 1 motorcycle, 1 stop sign, 139.9ms
# Speed: 2.1ms preprocess, 139.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x352 1 matricula, 102.2ms
# Speed: 1.5ms preprocess, 102.2ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 352)
#
# 0: 640x384 1 motorcycle, 1 stop sign, 117.3ms
# Speed: 1.0ms preprocess, 117.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x320 1 matricula, 70.2ms
# Speed: 0.0ms preprocess, 70.2ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 320)
#
# 0: 640x384 1 motorcycle, 1 stop sign, 135.2ms
# Speed: 2.2ms preprocess, 135.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x320 1 matricula, 96.1ms
# Speed: 1.8ms preprocess, 96.1ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 320)
#
# 0: 640x384 1 motorcycle, 1 stop sign, 129.1ms
# Speed: 1.0ms preprocess, 129.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x320 1 matricula, 89.7ms
# Speed: 1.0ms preprocess, 89.7ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 320)
#
# 0: 640x384 1 motorcycle, 1 stop sign, 122.2ms
# Speed: 2.0ms preprocess, 122.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x320 1 matricula, 99.9ms
# Speed: 2.6ms preprocess, 99.9ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 320)
#
# 0: 640x384 1 motorcycle, 1 stop sign, 119.1ms
# Speed: 2.5ms preprocess, 119.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x320 1 matricula, 88.6ms
# Speed: 1.0ms preprocess, 88.6ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 320)
#
# 0: 640x384 1 motorcycle, 130.8ms
# Speed: 2.0ms preprocess, 130.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x288 1 matricula, 96.1ms
# Speed: 0.0ms preprocess, 96.1ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 288)
#
# 0: 640x384 1 motorcycle, 1 stop sign, 133.2ms
# Speed: 3.0ms preprocess, 133.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x288 (no detections), 86.9ms
# Speed: 1.0ms preprocess, 86.9ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 288)
#
# 0: 640x384 1 motorcycle, 1 stop sign, 127.1ms
# Speed: 1.1ms preprocess, 127.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x224 (no detections), 98.4ms
# Speed: 1.0ms preprocess, 98.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 224)
#
# 0: 640x384 1 car, 1 truck, 1 stop sign, 129.3ms
# Speed: 1.1ms preprocess, 129.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x192 (no detections), 72.3ms
# Speed: 1.0ms preprocess, 72.3ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 192)
#
# 0: 640x384 1 car, 1 truck, 135.7ms
# Speed: 2.0ms preprocess, 135.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x128 (no detections), 67.1ms
# Speed: 0.5ms preprocess, 67.1ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 128)
#
# 0: 640x384 2 cars, 1 stop sign, 127.8ms
# Speed: 1.5ms preprocess, 127.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x256 (no detections), 115.5ms
# Speed: 1.0ms preprocess, 115.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 256)
#
# 0: 416x128 (no detections), 82.6ms
# Speed: 1.0ms preprocess, 82.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 128)
#
# 0: 640x384 1 car, 1 stop sign, 117.2ms
# Speed: 2.0ms preprocess, 117.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x192 (no detections), 67.4ms
# Speed: 1.0ms preprocess, 67.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
#
# 0: 640x384 1 car, 1 stop sign, 114.0ms
# Speed: 2.5ms preprocess, 114.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x256 (no detections), 69.7ms
# Speed: 1.5ms preprocess, 69.7ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 256)
#
# 0: 640x384 1 car, 1 stop sign, 130.6ms
# Speed: 2.0ms preprocess, 130.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x352 (no detections), 84.1ms
# Speed: 1.7ms preprocess, 84.1ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 352)
#
# 0: 640x384 1 car, 139.9ms
# Speed: 1.6ms preprocess, 139.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x320 (no detections), 79.2ms
# Speed: 2.0ms preprocess, 79.2ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 320)
#
# 0: 640x384 1 car, 123.8ms
# Speed: 2.5ms preprocess, 123.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x384 (no detections), 80.9ms
# Speed: 1.0ms preprocess, 80.9ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 640x384 1 car, 117.0ms
# Speed: 2.6ms preprocess, 117.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x384 (no detections), 115.0ms
# Speed: 0.9ms preprocess, 115.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 640x384 1 car, 1 stop sign, 98.0ms
# Speed: 1.9ms preprocess, 98.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x384 1 matricula, 84.3ms
# Speed: 0.9ms preprocess, 84.3ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 384)
#
# 0: 640x384 1 car, 124.2ms
# Speed: 3.1ms preprocess, 124.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x416 1 matricula, 108.7ms
# Speed: 2.0ms preprocess, 108.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 640x384 1 car, 111.8ms
# Speed: 3.0ms preprocess, 111.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x416 1 matricula, 77.6ms
# Speed: 1.0ms preprocess, 77.6ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 640x384 1 car, 116.9ms
# Speed: 3.0ms preprocess, 116.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x416 1 matricula, 91.2ms
# Speed: 2.0ms preprocess, 91.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 416)
#
# 0: 640x384 1 car, 125.8ms
# Speed: 2.4ms preprocess, 125.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 384x416 1 matricula, 94.6ms
# Speed: 1.0ms preprocess, 94.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 416)
#
# 0: 640x384 1 car, 126.4ms
# Speed: 2.6ms preprocess, 126.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 352x416 1 matricula, 119.0ms
# Speed: 1.0ms preprocess, 119.0ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 416)
#
# 0: 640x384 1 car, 116.9ms
# Speed: 1.1ms preprocess, 116.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 320x416 1 matricula, 97.2ms
# Speed: 1.6ms preprocess, 97.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 640x384 1 car, 115.9ms
# Speed: 2.7ms preprocess, 115.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 320x416 1 matricula, 69.6ms
# Speed: 1.0ms preprocess, 69.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 640x384 1 car, 133.2ms
# Speed: 1.5ms preprocess, 133.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 320x416 1 matricula, 85.9ms
# Speed: 1.0ms preprocess, 85.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 640x384 1 car, 110.5ms
# Speed: 2.0ms preprocess, 110.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 320x416 1 matricula, 75.6ms
# Speed: 1.0ms preprocess, 75.6ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 640x384 1 car, 136.1ms
# Speed: 2.0ms preprocess, 136.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 288x416 2 matriculas, 114.5ms
# Speed: 3.0ms preprocess, 114.5ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 416)
#
# 0: 640x384 1 car, 153.1ms
# Speed: 2.0ms preprocess, 153.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 288x416 1 matricula, 104.9ms
# Speed: 1.0ms preprocess, 104.9ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 416)
#
# 0: 640x384 1 car, 126.7ms
# Speed: 3.5ms preprocess, 126.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 288x416 1 matricula, 86.6ms
# Speed: 0.9ms preprocess, 86.6ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 416)
#
# 0: 640x384 1 car, 109.2ms
# Speed: 1.0ms preprocess, 109.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 288x416 2 matriculas, 77.4ms
# Speed: 0.5ms preprocess, 77.4ms inference, 2.0ms postprocess per image at shape (1, 3, 288, 416)
#
# 0: 640x384 1 car, 82.4ms
# Speed: 2.0ms preprocess, 82.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 288x416 3 matriculas, 85.0ms
# Speed: 2.0ms preprocess, 85.0ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 416)
#
# 0: 640x384 1 car, 100.4ms
# Speed: 1.0ms preprocess, 100.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 288x416 3 matriculas, 82.6ms
# Speed: 1.0ms preprocess, 82.6ms inference, 0.0ms postprocess per image at shape (1, 3, 288, 416)
#
# 0: 640x384 1 car, 116.0ms
# Speed: 2.0ms preprocess, 116.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 288x416 3 matriculas, 80.9ms
# Speed: 2.0ms preprocess, 80.9ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 416)
#
# 0: 640x384 1 car, 130.6ms
# Speed: 1.0ms preprocess, 130.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 2 matriculas, 101.8ms
# Speed: 2.0ms preprocess, 101.8ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 1 car, 145.2ms
# Speed: 2.3ms preprocess, 145.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 3 matriculas, 84.4ms
# Speed: 1.0ms preprocess, 84.4ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 1 car, 122.1ms
# Speed: 2.3ms preprocess, 122.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 2 matriculas, 116.6ms
# Speed: 1.0ms preprocess, 116.6ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 1 car, 131.7ms
# Speed: 1.1ms preprocess, 131.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 3 matriculas, 82.2ms
# Speed: 1.0ms preprocess, 82.2ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 1 car, 116.4ms
# Speed: 2.1ms preprocess, 116.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 2 matriculas, 73.6ms
# Speed: 0.0ms preprocess, 73.6ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 1 car, 138.5ms
# Speed: 2.0ms preprocess, 138.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 2 matriculas, 86.7ms
# Speed: 1.6ms preprocess, 86.7ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 1 car, 107.3ms
# Speed: 2.0ms preprocess, 107.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 2 matriculas, 72.7ms
# Speed: 0.0ms preprocess, 72.7ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 1 car, 103.9ms
# Speed: 1.0ms preprocess, 103.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 2 matriculas, 72.5ms
# Speed: 1.0ms preprocess, 72.5ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 1 car, 113.2ms
# Speed: 2.1ms preprocess, 113.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 2 matriculas, 83.4ms
# Speed: 1.0ms preprocess, 83.4ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 1 car, 140.5ms
# Speed: 2.2ms preprocess, 140.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 1 matricula, 66.2ms
# Speed: 0.9ms preprocess, 66.2ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 1 car, 125.5ms
# Speed: 1.0ms preprocess, 125.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 2 matriculas, 103.7ms
# Speed: 1.0ms preprocess, 103.7ms inference, 2.3ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 1 car, 116.7ms
# Speed: 2.9ms preprocess, 116.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 2 matriculas, 83.2ms
# Speed: 1.0ms preprocess, 83.2ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 1 car, 126.1ms
# Speed: 2.0ms preprocess, 126.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 3 matriculas, 83.5ms
# Speed: 1.0ms preprocess, 83.5ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 1 car, 112.0ms
# Speed: 2.0ms preprocess, 112.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 2 matriculas, 82.1ms
# Speed: 1.0ms preprocess, 82.1ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 1 car, 127.4ms
# Speed: 2.0ms preprocess, 127.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 3 matriculas, 85.9ms
# Speed: 1.2ms preprocess, 85.9ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 1 car, 114.6ms
# Speed: 2.3ms preprocess, 114.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 2 matriculas, 83.9ms
# Speed: 1.0ms preprocess, 83.9ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 1 car, 139.8ms
# Speed: 2.0ms preprocess, 139.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 1 matricula, 87.0ms
# Speed: 2.0ms preprocess, 87.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 1 car, 103.0ms
# Speed: 1.1ms preprocess, 103.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 2 matriculas, 89.5ms
# Speed: 2.2ms preprocess, 89.5ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 1 car, 109.7ms
# Speed: 1.9ms preprocess, 109.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 2 matriculas, 86.3ms
# Speed: 1.0ms preprocess, 86.3ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 1 car, 102.8ms
# Speed: 3.0ms preprocess, 102.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 2 matriculas, 80.8ms
# Speed: 1.0ms preprocess, 80.8ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 1 car, 104.9ms
# Speed: 1.5ms preprocess, 104.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 3 matriculas, 67.1ms
# Speed: 1.0ms preprocess, 67.1ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 1 car, 115.3ms
# Speed: 2.0ms preprocess, 115.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 3 matriculas, 84.6ms
# Speed: 1.5ms preprocess, 84.6ms inference, 1.5ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 1 car, 116.1ms
# Speed: 2.0ms preprocess, 116.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 2 matriculas, 74.5ms
# Speed: 1.0ms preprocess, 74.5ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 1 car, 113.2ms
# Speed: 2.5ms preprocess, 113.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 2 matriculas, 74.3ms
# Speed: 1.0ms preprocess, 74.3ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 1 car, 113.5ms
# Speed: 1.9ms preprocess, 113.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 2 matriculas, 92.7ms
# Speed: 2.0ms preprocess, 92.7ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 1 car, 123.0ms
# Speed: 2.0ms preprocess, 123.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 2 matriculas, 83.9ms
# Speed: 1.0ms preprocess, 83.9ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 1 car, 128.6ms
# Speed: 1.6ms preprocess, 128.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 1 matricula, 84.6ms
# Speed: 1.0ms preprocess, 84.6ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 1 car, 114.2ms
# Speed: 2.0ms preprocess, 114.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 1 matricula, 70.4ms
# Speed: 1.0ms preprocess, 70.4ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 1 car, 145.1ms
# Speed: 0.9ms preprocess, 145.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 1 matricula, 113.0ms
# Speed: 1.0ms preprocess, 113.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 1 car, 121.5ms
# Speed: 2.7ms preprocess, 121.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 2 matriculas, 63.8ms
# Speed: 1.0ms preprocess, 63.8ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 1 car, 107.5ms
# Speed: 2.0ms preprocess, 107.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 2 matriculas, 77.6ms
# Speed: 1.0ms preprocess, 77.6ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 1 car, 108.0ms
# Speed: 2.2ms preprocess, 108.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 2 matriculas, 77.6ms
# Speed: 1.1ms preprocess, 77.6ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 1 car, 129.5ms
# Speed: 2.1ms preprocess, 129.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 2 matriculas, 79.8ms
# Speed: 1.1ms preprocess, 79.8ms inference, 1.6ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 1 car, 141.9ms
# Speed: 2.7ms preprocess, 141.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 2 matriculas, 84.0ms
# Speed: 2.0ms preprocess, 84.0ms inference, 0.9ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 1 car, 130.0ms
# Speed: 1.0ms preprocess, 130.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 3 matriculas, 88.3ms
# Speed: 1.5ms preprocess, 88.3ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 1 car, 113.5ms
# Speed: 1.0ms preprocess, 113.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 3 matriculas, 98.1ms
# Speed: 1.0ms preprocess, 98.1ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 1 car, 129.2ms
# Speed: 1.0ms preprocess, 129.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 2 matriculas, 90.3ms
# Speed: 2.0ms preprocess, 90.3ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 1 car, 121.7ms
# Speed: 2.5ms preprocess, 121.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 3 matriculas, 88.4ms
# Speed: 0.0ms preprocess, 88.4ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 1 car, 112.8ms
# Speed: 2.0ms preprocess, 112.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 1 matricula, 84.5ms
# Speed: 1.0ms preprocess, 84.5ms inference, 2.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 1 car, 151.9ms
# Speed: 2.0ms preprocess, 151.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 2 matriculas, 105.5ms
# Speed: 1.1ms preprocess, 105.5ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 1 car, 131.9ms
# Speed: 2.0ms preprocess, 131.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 2 matriculas, 82.7ms
# Speed: 1.0ms preprocess, 82.7ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 1 car, 132.2ms
# Speed: 1.5ms preprocess, 132.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 1 matricula, 80.7ms
# Speed: 1.1ms preprocess, 80.7ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 1 car, 108.3ms
# Speed: 2.0ms preprocess, 108.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 2 matriculas, 63.3ms
# ...
#
# 0: 224x416 (no detections), 43.2ms
# Speed: 1.0ms preprocess, 43.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 416)
#
# 0: 640x384 2 cars, 62.1ms
# Speed: 1.9ms preprocess, 62.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 1 matricula, 43.0ms
# Speed: 1.0ms preprocess, 43.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 160x416 (no detections), 47.3ms
# Speed: 1.0ms preprocess, 47.3ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 416)
#
# 0: 640x384 3 cars, 86.5ms
# Speed: 1.5ms preprocess, 86.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 (no detections), 46.9ms
# Speed: 0.9ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 45.3ms
# Speed: 1.0ms preprocess, 45.3ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 47.9ms
# Speed: 0.9ms preprocess, 47.9ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 3 cars, 78.0ms
# Speed: 2.0ms preprocess, 78.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 1 matricula, 41.4ms
# Speed: 1.1ms preprocess, 41.4ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 320x416 (no detections), 53.0ms
# Speed: 0.0ms preprocess, 53.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 224x416 (no detections), 43.0ms
# Speed: 1.0ms preprocess, 43.0ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 416)
#
# 0: 640x384 2 cars, 1 fire hydrant, 78.4ms
# Speed: 2.5ms preprocess, 78.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 (no detections), 40.1ms
# Speed: 1.0ms preprocess, 40.1ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 41.9ms
# Speed: 0.0ms preprocess, 41.9ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 2 cars, 64.7ms
# Speed: 2.0ms preprocess, 64.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 (no detections), 42.3ms
# Speed: 1.0ms preprocess, 42.3ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 45.0ms
# Speed: 1.1ms preprocess, 45.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 3 cars, 63.4ms
# Speed: 2.0ms preprocess, 63.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 1 matricula, 43.4ms
# Speed: 0.9ms preprocess, 43.4ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 41.1ms
# Speed: 1.0ms preprocess, 41.1ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 288x416 (no detections), 47.2ms
# Speed: 1.0ms preprocess, 47.2ms inference, 0.0ms postprocess per image at shape (1, 3, 288, 416)
#
# 0: 640x384 2 cars, 69.3ms
# Speed: 2.0ms preprocess, 69.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 1 matricula, 46.4ms
# Speed: 0.0ms preprocess, 46.4ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 256x416 (no detections), 42.9ms
# Speed: 1.0ms preprocess, 42.9ms inference, 1.7ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 2 cars, 65.6ms
# Speed: 1.9ms preprocess, 65.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 288x416 (no detections), 45.5ms
# Speed: 0.0ms preprocess, 45.5ms inference, 0.0ms postprocess per image at shape (1, 3, 288, 416)
#
# 0: 224x416 (no detections), 43.4ms
# Speed: 1.0ms preprocess, 43.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 416)
#
# 0: 640x384 2 cars, 75.1ms
# Speed: 2.0ms preprocess, 75.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 320x416 (no detections), 44.6ms
# Speed: 0.9ms preprocess, 44.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 224x416 (no detections), 38.7ms
# Speed: 1.0ms preprocess, 38.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 416)
#
# 0: 640x384 3 cars, 66.7ms
# Speed: 1.0ms preprocess, 66.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 352x416 (no detections), 58.2ms
# Speed: 0.0ms preprocess, 58.2ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 416)
#
# 0: 224x416 (no detections), 41.8ms
# Speed: 1.6ms preprocess, 41.8ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 416)
#
# 0: 352x416 (no detections), 52.9ms
# Speed: 1.0ms preprocess, 52.9ms inference, 0.0ms postprocess per image at shape (1, 3, 352, 416)
#
# 0: 640x384 2 cars, 74.8ms
# Speed: 2.1ms preprocess, 74.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x416 (no detections), 82.2ms
# Speed: 0.9ms preprocess, 82.2ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 224x416 (no detections), 40.8ms
# Speed: 1.0ms preprocess, 40.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 416)
#
# 0: 640x384 2 cars, 63.3ms
# Speed: 0.9ms preprocess, 63.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x352 (no detections), 57.8ms
# Speed: 1.0ms preprocess, 57.8ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 352)
#
# 0: 224x416 (no detections), 38.8ms
# Speed: 0.0ms preprocess, 38.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 416)
#
# 0: 640x384 1 person, 2 cars, 63.5ms
# Speed: 1.6ms preprocess, 63.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x256 (no detections), 61.6ms
# Speed: 1.1ms preprocess, 61.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 256)
#
# 0: 224x416 (no detections), 63.7ms
# Speed: 0.0ms preprocess, 63.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 416)
#
# 0: 640x384 3 cars, 77.2ms
# Speed: 1.9ms preprocess, 77.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 416x160 (no detections), 44.5ms
# Speed: 1.0ms preprocess, 44.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 160)
#
# 0: 224x416 (no detections), 46.5ms
# Speed: 1.0ms preprocess, 46.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 416)
#
# 0: 288x416 (no detections), 44.1ms
# Speed: 1.0ms preprocess, 44.1ms inference, 0.0ms postprocess per image at shape (1, 3, 288, 416)
#
# 0: 640x384 1 person, 1 car, 80.9ms
# Speed: 1.1ms preprocess, 80.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 224x416 (no detections), 43.1ms
# Speed: 0.9ms preprocess, 43.1ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 416)
#
# 0: 640x384 2 cars, 61.5ms
# Speed: 1.6ms preprocess, 61.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 (no detections), 45.2ms
# Speed: 1.0ms preprocess, 45.2ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 288x416 (no detections), 54.4ms
# Speed: 1.0ms preprocess, 54.4ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 416)
#
# 0: 640x384 1 car, 79.9ms
# Speed: 2.5ms preprocess, 79.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 224x416 (no detections), 44.6ms
# Speed: 1.0ms preprocess, 44.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 416)
#
# 0: 640x384 1 car, 82.7ms
# Speed: 1.0ms preprocess, 82.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 224x416 (no detections), 43.2ms
# Speed: 1.0ms preprocess, 43.2ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 416)
#
# 0: 640x384 1 car, 105.6ms
# Speed: 2.0ms preprocess, 105.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 (no detections), 51.6ms
# Speed: 1.0ms preprocess, 51.6ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 1 car, 70.5ms
# Speed: 1.0ms preprocess, 70.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 192x416 (no detections), 47.0ms
# Speed: 1.0ms preprocess, 47.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 416)
#
# 0: 640x384 2 cars, 73.9ms
# Speed: 1.5ms preprocess, 73.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 224x416 (no detections), 39.0ms
# Speed: 0.0ms preprocess, 39.0ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 416)
#
# 0: 384x416 (no detections), 63.3ms
# Speed: 1.1ms preprocess, 63.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 416)
#
# 0: 640x384 2 cars, 63.2ms
# Speed: 1.4ms preprocess, 63.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 192x416 (no detections), 34.0ms
# Speed: 0.0ms preprocess, 34.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 416)
#
# 0: 384x416 (no detections), 55.8ms
# Speed: 1.0ms preprocess, 55.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 416)
#
# 0: 640x384 1 car, 68.6ms
# Speed: 1.0ms preprocess, 68.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 224x416 (no detections), 44.6ms
# Speed: 0.0ms preprocess, 44.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 416)
#
# 0: 640x384 2 cars, 1 fire hydrant, 62.8ms
# Speed: 1.0ms preprocess, 62.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 (no detections), 40.4ms
# Speed: 0.0ms preprocess, 40.4ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 384x416 (no detections), 47.5ms
# Speed: 1.0ms preprocess, 47.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 416)
#
# 0: 640x384 1 car, 1 fire hydrant, 79.8ms
# Speed: 2.0ms preprocess, 79.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 224x416 (no detections), 40.9ms
# Speed: 1.0ms preprocess, 40.9ms inference, 0.9ms postprocess per image at shape (1, 3, 224, 416)
#
# 0: 640x384 1 car, 65.8ms
# Speed: 1.0ms preprocess, 65.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 (no detections), 42.2ms
# Speed: 0.9ms preprocess, 42.2ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 2 cars, 66.1ms
# Speed: 1.0ms preprocess, 66.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 224x416 (no detections), 42.3ms
# Speed: 1.0ms preprocess, 42.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 416)
#
# 0: 224x416 (no detections), 48.1ms
# Speed: 0.0ms preprocess, 48.1ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 416)
#
# 0: 640x384 2 cars, 81.3ms
# Speed: 2.0ms preprocess, 81.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 224x416 (no detections), 41.6ms
# Speed: 1.0ms preprocess, 41.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 416)
#
# 0: 320x416 (no detections), 47.4ms
# Speed: 0.9ms preprocess, 47.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
#
# 0: 640x384 1 car, 1 fire hydrant, 74.3ms
# Speed: 1.5ms preprocess, 74.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 224x416 (no detections), 40.5ms
# Speed: 0.0ms preprocess, 40.5ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 416)
#
# 0: 640x384 2 cars, 1 fire hydrant, 62.3ms
# Speed: 2.1ms preprocess, 62.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 224x416 (no detections), 51.5ms
# Speed: 1.0ms preprocess, 51.5ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 416)
#
# 0: 224x416 (no detections), 57.0ms
# Speed: 1.0ms preprocess, 57.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 416)
#
# 0: 640x384 2 cars, 1 fire hydrant, 68.4ms
# Speed: 1.5ms preprocess, 68.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 (no detections), 60.3ms
# Speed: 0.0ms preprocess, 60.3ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 224x416 (no detections), 50.0ms
# Speed: 1.0ms preprocess, 50.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 416)
#
# 0: 640x384 2 cars, 1 fire hydrant, 55.0ms
# Speed: 1.0ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 224x416 (no detections), 39.2ms
# Speed: 1.0ms preprocess, 39.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 416)
#
# 0: 224x416 (no detections), 42.6ms
# Speed: 1.0ms preprocess, 42.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 416)
#
# 0: 640x384 2 cars, 1 fire hydrant, 67.8ms
# Speed: 2.0ms preprocess, 67.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 224x416 (no detections), 39.5ms
# Speed: 1.0ms preprocess, 39.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 416)
#
# 0: 288x416 (no detections), 48.1ms
# Speed: 1.0ms preprocess, 48.1ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 416)
#
# 0: 640x384 2 cars, 1 fire hydrant, 64.0ms
# Speed: 2.0ms preprocess, 64.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 224x416 (no detections), 42.6ms
# Speed: 1.0ms preprocess, 42.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 416)
#
# 0: 416x416 (no detections), 60.8ms
# Speed: 0.0ms preprocess, 60.8ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 640x384 2 cars, 86.5ms
# Speed: 2.0ms preprocess, 86.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 224x416 (no detections), 45.0ms
# Speed: 1.0ms preprocess, 45.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 416)
#
# 0: 224x416 (no detections), 41.6ms
# Speed: 0.9ms preprocess, 41.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 416)
#
# 0: 640x384 1 car, 86.4ms
# Speed: 1.1ms preprocess, 86.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 224x416 (no detections), 61.3ms
# Speed: 1.0ms preprocess, 61.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 416)
#
# 0: 640x384 1 car, 3 fire hydrants, 94.2ms
# Speed: 2.0ms preprocess, 94.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 288x416 (no detections), 58.3ms
# Speed: 0.0ms preprocess, 58.3ms inference, 0.0ms postprocess per image at shape (1, 3, 288, 416)
#
# 0: 640x384 2 cars, 67.4ms
# Speed: 2.0ms preprocess, 67.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 (no detections), 48.1ms
# Speed: 0.0ms preprocess, 48.1ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 352x416 (no detections), 57.7ms
# Speed: 1.1ms preprocess, 57.7ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 416)
#
# 0: 640x384 1 car, 1 fire hydrant, 68.4ms
# Speed: 2.5ms preprocess, 68.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 224x416 (no detections), 45.6ms
# Speed: 1.0ms preprocess, 45.6ms inference, 1.1ms postprocess per image at shape (1, 3, 224, 416)
#
# 0: 640x384 1 car, 2 fire hydrants, 73.2ms
# Speed: 1.9ms preprocess, 73.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 (no detections), 43.8ms
# Speed: 1.0ms preprocess, 43.8ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 640x384 1 car, 3 fire hydrants, 89.8ms
# Speed: 1.0ms preprocess, 89.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 224x416 (no detections), 47.8ms
# Speed: 1.0ms preprocess, 47.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 416)
#
# 0: 640x384 2 cars, 59.2ms
# Speed: 1.0ms preprocess, 59.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 256x416 (no detections), 42.6ms
# Speed: 1.0ms preprocess, 42.6ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 416)
#
# 0: 224x416 (no detections), 52.7ms
# Speed: 1.0ms preprocess, 52.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 416)
#
# 0: 640x384 2 cars, 68.6ms
# Speed: 1.0ms preprocess, 68.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 224x416 (no detections), 47.3ms
# Speed: 0.0ms preprocess, 47.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 416)
#
# 0: 256x416 (no detections), 50.0ms
# Speed: 1.0ms preprocess, 50.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 416)
